# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
os.chdir("C:/Users/satrajit/Desktop/SATRAJIT/QualySense_data/NIRworkshop")

# %%
DarkReference = pd.read_excel("DarkReference.xlsx", header=None)
RawSpectra = pd.read_excel("DarkReference.xlsx", header=None)
ReferenceValues = pd.read_excel("ReferenceValues.xlsx", header=None)
SampleID = pd.read_excel("SampleID.xlsx", header=None)
SpectraTotal = pd.read_excel("SpectraTotal.xlsx", header=None)
WhiteReference = pd.read_excel("WhiteReference.xlsx", header=None)
Wavenumber = pd.read_excel("xaxis.xlsx", header=None)

SpectraTotal.head()
# Out:
#        0         1         2         3         4         5         6     \
# 0  0.097267  0.096657  0.096480  0.096897  0.097240  0.096947  0.096477
# 1  0.096988  0.096648  0.096203  0.096033  0.095943  0.095904  0.095944
# 2  0.097532  0.098087  0.098566  0.098479  0.097804  0.097231  0.097261
# 3  0.099838  0.099242  0.098341  0.098155  0.098293  0.097994  0.097563
# 4  0.099213  0.098329  0.097819  0.098112  0.098678  0.098873  0.098816
#
#        7         8         9       ...         1144      1145      1146  \
# 0  0.096288  0.096318  0.096470    ...     1.390576  1.467817  1.542275
# 1  0.095786  0.095610  0.095591    ...     1.388595  1.462359  1.534217
# 2  0.097598  0.097786  0.097796    ...     1.386841  1.465200  1.540868
# 3  0.097547  0.097918  0.098035    ...     1.358260  1.429768  1.498949
# 4  0.098700  0.098634  0.098732    ...     1.385509  1.462066  1.534997
#
#        1147      1148      1149      1150      1151      1152      1153
# ...

# %%
plt.plot(S)
